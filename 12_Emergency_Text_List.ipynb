# %% [markdown]
# # 위급 상황 텍스트 리스트

# %% [markdown]
# # 0. metadata 불러오기

# %%
import pandas as pd

file_path = 'metadata.csv'
data = pd.read_csv(file_path)

data
# Out:
#                                                file_name        text  label
# 0      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105083_labe...  내 몸에 손대지 마      1
# 1      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105137_labe...     만지지 마세요      1
# 2      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105448_labe...       만지지 마      1
# 3      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105512_labe...  내 몸에 손대지 마      1
# 4      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105589_labe...       만지지 마      1
# ...                                                  ...         ...    ...
# 78611         train\audio\9.가스사고\9.가스사고_709436_label.wav      가스 터진다      9
# 78612         train\audio\9.가스사고\9.가스사고_709441_label.wav      가스 터진다      9
# 78613         train\audio\9.가스사고\9.가스사고_709513_label.wav      가스 터진다      9
# 78614         train\audio\9.가스사고\9.가스사고_709576_label.wav  가스 터진 거 같아      9
# 78615         train\audio\9.가스사고\9.가스사고_709651_label.wav      가스 터졌다      9
#
# [78616 rows x 3 columns]

# %%
import pandas as pd

df = pd.read_csv('metadata.csv')

selected_rows = df[df['label'].between(1, 14)]

# 중복 제거하고 각 텍스트의 중복 횟수 카운트
text_counts = selected_rows.groupby(['text', 'label']).size().reset_index(name='count')

text_counts
# Out:
#              text  label  count
# 0       112 좀 불러줘      4     26
# 1       112 좀 불러줘     14      2
# 2    112에 신고에 주세요     14     39
# 3        112에 신고해     14      3
# 4    112에 신고해 주세요     14     23
# ..            ...    ...    ...
# 850          화재났어      5     74
# 851           화재다      5     76
# 852          훔쳐갔어      3      3
# 853      흙에 파묻혔어요     11    128
# 854       흙이 덮쳤어요     11    110
#
# [855 rows x 3 columns]

# %%
text_counts.to_csv('text_counts.csv', index=False)

# %%
import pandas as pd
from collections import Counter

df = pd.read_csv('metadata.csv')

selected_rows = df[df['label'].between(1, 14)]

text_counter = Counter(selected_rows['text'])

# 중복된 횟수에 따라 정렬된 사전 생성
sorted_text_dict = dict(sorted(text_counter.items(), key=lambda item: item[1], reverse=True))

sorted_text_dict
# Out:
# {'도둑이야': 1502,
#  '미끄러졌어요': 1398,
#  '도둑 잡아': 760,
#  '때리지 마세요': 669,
#  '지진이다': 654,
#  '가스 터진다': 642,
#  '갇혔나 봐': 598,
#  '만지지 마세요': 502,
#  '살려주세요': 489,
#  '짜증나게 하지 마': 481,
#  '내 몸 만지지 마': 469,
#  '때리지 마': 469,
#  '내 몸에 손대지 마': 440,
#  '짜증나게 할래': 430,
#  '죽을래': 427,
#  '가스 터진 거 같아': 425,
#  '짜증 나네': 424,
#  '대피하세요': 401,
#  '만지지 마': 351,
#  '대피해': 343,
#  '배기통 터졌다': 316,
#  '어딜 손대': 312,
#  '갇힌 것 같아': 312,
#  '어딜 만져': 307,
#  '도와주세요': 299,
#  '제발 때리지 마세요': 290,
#  '죽고 싶어': 289,
#  '손대지 마': 284,
#  '가스 터졌다': 278,
#  '불났다': 266,
#  '건물이 흔들려요': 248,
#  '소화기 어딨어': 248,
#  '신고 좀 해주세요': 233,
#  '때리지 말란 말이야': 233,
#  '구해주세요': 215,
#  '맞고 싶냐': 212,
#  '도망쳐': 206,
#  '땅이 흔들려요': 202,
#  '건물이 붕괴됐어요': 200,
#  '여기 불났어요': 197,
#  '119 불러주세요': 196,
#  '도망가': 194,
#  '도망가라': 192,
#  '집이 흔들린다': 191,
#  '무너지는 소리가 나요': 188,
#  '밖으로 나가': 188,
#  '도로가 잠겼어요': 183,
#  '소화기 가져와': 181,
#  '집이 무너졌어요': 180,
#  '지진 신고해': 180,
#  '구조해 주세요': 179,
#  '도망가세요': 178,
#  '다리가 무너졌어요': 175,
#  '갑자기 쓰러졌어요': 173,
# ...

# %%
# 맞춤법 교정 사전
correction_dict = {
    '도둑잡아': '도둑 잡아',
    '갇혔나봐': '갇혔나 봐',
    '짜증나게하지마': '짜증나게 하지 마',
    '내몸만지지마': '내 몸 만지지 마',
    '내몸에손대지마': '내 몸에 손대지 마',
    '짜증나게할래': '짜증나게 할래',
    '만지지마세요': '만지지 마세요',
    '짜증나네': '짜증 나네',
    '만지지마': '만지지 마',
    '가스터진거같아': '가스 터진 거 같아',
    '가스터진다': '가스 터진다',
    '어딜손대': '어딜 손대',
    '때리지마세요': '때리지 마세요',
    '어딜만져': '어딜 만져',
    '죽고싶어': '죽고 싶어',
    '손대지마': '손대지 마',
    '갇힌것같아': '갇힌 것 같아',
    '때리지마': '때리지 마',
    '맞고싶냐': '맞고 싶냐',
    '구조해주세요': '구조해 주세요',
    '죽고싶냐': '죽고 싶냐',
    '저 놈 잡아라': '저놈 잡아라',
    '바람이너무세다': '바람이 너무 세다',
    '제발 때리지 마세요 다시 안 그럴께요': '제발 때리지 마세요. 다시 안 그럴게요',
    '붕괴되는거아니야': '붕괴되는 거 아니야',
    '도로에 장애물이있어요': '도로에 장애물이 있어요',
    '가진거 다 내놔': '가진 거 다 내놔',
    '대피해주세요': '대피해 주세요',
    '바람세니까조심해': '바람 세니까 조심해',
    '머리를 부닺혔어요': '머리를 부딪혔어요',
    '입막아': '입 막아',
    '물이 들어 오고 있어요': '물이 들어오고 있어요',
    '바람이너무세게불어': '바람이 너무 세게 불어',
    '바람이너무심해': '바람이 너무 심해',
    '피나온다': '피 나온다',
    '코드 만지지마': '코드 만지지 마',
    '바람너무분다': '바람 너무 분다',
    '맞고싶어': '맞고 싶어',
    '소화기어딨어': '소화기 어딨어',
    '도와 주세요': '도와주세요',
    '누가 도와 주세요': '누가 도와주세요',
    '강아지피해': '강아지 피해',
    '뼈부러졌어': '뼈 부러졌어',
    '전선 만지지마': '전선 만지지 마',
    '구조해줘': '구조해 줘',
    '무너져내려갔어요': '무너져 내려갔어요',
    '구급차불러줘': '구급차 불러줘',
    '강풍조심해': '강풍 조심해',
    '빨리 도와 주세요': '빨리 도와주세요',
    '연기난다': '연기 난다',
    '제발 누가 좀 도와 주세요': '제발 누가 좀 도와주세요',
    '코드 손대지마': '코드 손대지 마',
    '뼈부러졌네': '뼈 부러졌네',
    '개만지지마': '개 만지지 마',
    '비상구가 안보여': '비상구가 안 보여',
    '물들어온다': '물 들어온다',
    '몸이 안움직여요': '몸이 안 움직여요',
    '하지마': '하지 마',
    '구출해주세요': '구출해 주세요',
    '119불러주세요': '119 불러주세요',
    '비상구어딨어': '비상구 어딨어',
    '전선 밟지마': '전선 밟지 마',
    '제발 때리지 마세요 다시 안그럴게요': '제발 때리지 마세요. 다시 안 그럴게요',
    '피나는거아니야': '피 나는 거 아니야',
    '가스 새는거 같아': '가스 새는 거 같아',
    '소화기필요해': '소화기 필요해',
    '연기때문에 숨을 못쉬겠어': '연기 때문에 숨을 못 쉬겠어',
    '배기통터졌다': '배기통 터졌다',
    '하지말라고': '하지 말라고',
    '의식이없어': '의식이 없어',
    '못일어나겠어': '못 일어나겠어',
    '비상구로뛰어': '비상구로 뛰어',
    '가스터졌다': '가스 터졌다',
    '넌 맞아야돼': '넌 맞아야 돼',
    '뼈가부러졌어': '뼈가 부러졌어',
    '바로 출동해주세요': '바로 출동해 주세요',
    '출혈이크네': '출혈이 크네',
    '여진이 오고있어요': '여진이 오고 있어요',
    '스위치만지지마': '스위치 만지지 마',
    '강풍분다': '강풍 분다',
    '이러지마': '이러지 마',
    '강풍부니까나가지마': '강풍 부니까 나가지 마',
    '이것 밖에 없어요': '이것밖에 없어요',
    '붕괴될거같아': '붕괴될 거 같아',
    '너 이리와 봐': '너 이리 와 봐',
    '구출해줘': '구출해 줘',
    '112에전화해': '112에 전화해',
    '홍수났어': '홍수 났어',
    '이건 안돼요': '이건 안 돼요',
    '물이너무많이들어왔어': '물이 너무 많이 들어왔어',
    '산불이나고있어': '산불이 나고 있어',
    '소화기어딨지': '소화기 어딨지',
    '열이높아': '열이 높아',
    '멀티탭조심해': '멀티탭 조심해',
    '엘리베이터가 안움직여요': '엘리베이터가 안 움직여요',
    '가진게 이것 밖에 없어요': '가진 게 이것밖에 없어요',
    '입다물어': '입 다물어',
    '개조심해': '개 조심해',
    '비상구찾아': '비상구 찾아',
    '열이심해': '열이 심해',
    '강아지조심해': '강아지 조심해',
    '피가 계속나요': '피가 계속 나요',
    '지진조심해': '지진 조심해',
    '산불나는데': '산불 나는데',
    '플러그가이상해': '플러그가 이상헤',
    '합선된것같은데': '합선된 것 같은데',
    '연기 때문에 앞이 안보여': '연기 때문에 앞이 안 보여',
    '문이 고장났어요': '문이 고장 났어요',
    '제발 때리지마세요': '제발 때리지 마세요',
    '병원에 데려다 주세요': '병원에 데려다주세요',
    '열이안내려': '열이 안 내려',
    '합선된거아냐': '합선된 거 아냐',
    '플러그만지지마': '플러그 만지지 마',
    '이거 밖에 없어요': '이거밖에 없어요',
    '산사태가났어': '산사태가 났어',
    '강풍부는거같아': '강풍 부는 거 같아',
    '지진인거같아': '지진인 거 같아',
    '소화기가져와': '소화기 가져와',
    '플러그불량인가봐': '플러그 불량인가 봐',
    '제발 안돼요': '제발 안 돼요',
    '의식없어요': '의식 없어요',
    '119에신고해': '119에 신고해',
    '구급차어딨어': '구급차 어딨어',
    '콘센트에물들어갔어': '콘센트에 물 들어 갔어',
    '어구엉덩이야': '어구 엉덩이야',
    '맞을때 됐지': '맞을 때 됐지',
    '삐였지': '삐었지',
    '전기선만지지마': '전기선 만지지 마',
    '피복벗겨졌나봐': '피복 벗겨졌나 봐',
    '플러그에물들어갔어': '플러그에 물 들어갔어',
    '바람이너무쎄다': '바람이 너무 쎄다',
    '구급차필요해': '구급차 필요해',
    '스위치에물들어갔어': '스위치에 물 들어갔어',
    '멀티탭 만지지마': '멀티탭 만지지 마',
    '합선된것같아': '합선된 것 같아',
    '바람이너무분다': '바람이 너무 분다',
    '물이들어오는데': '물이 들어오는데',
    '바람이너무쎄게불어': '바람이 너무 세게 불어',
    '스위치불량인가봐': '스위치 불량인가 봐',
    '연기나고있어': '연기 나고 있어',
    '목아파요': '목 아파요',
    '멀티탭과부하오겠는데': '멀티탭 과부하 오겠는데',
    '출혈이심해': '출혈이 심해',
    '출혈이심하다': '출혈이 심하다',
    '스위치가탔어': '스위치가 탔어',
    '바람이쎄니까조심해': '바람이 세니까 조심해',
    '개사나워': '개 사나워',
    '전기선조심해': '전기선 조심해',
    '제발 그만때려요': '제발 그만 때려요',
    '산사태조심해': '산사태 조심해',
    '홍수날것같아': '홍수 날 것 같아',
    '전기선이이상해': '전기선이 이상해',
    '안돼요': '안 돼요',
    '으발목이야': '으 발목이야',
    '숨을 못쉬겠어': '숨을 못 쉬겠어',
    '112좀불러줘': '112 좀 불러줘',
    '악어우팔목이야': '악 어우 팔목이야',
    '제발 때리지 마세요 다시는 안그럴게요': '제발 때리지 마세요. 다시는 안 그럴게요',
    '통증이심해': '통증이 심해',
    '열나는것 같아': '열나는 것 같아',
    '콘센트조심해': '콘센트 조심해',
    '전선에 불 붙었어': '전선에 불붙었어',
    '의식이없다': '의식이 없다',
    '출혈이있어': '출혈이 있어',
    '강풍부는것같아': '강풍 부는 것 같아',
    '넌 말로 해선 안돼': '넌 말로 해선 안 돼',
    '과부하됐다': '과부하 됐다',
    '전기선벗겨졌어': '전기선 벗겨졌어',
    '신고부탁해': '신고 부탁해',
    '어무너진다': '어 무너진다',
    '119에전화해': '119에 전화해',
    '멀티탭만지지마': '멀티탭 만지지 마',
    '어우허리야': '어우 허리야',
    '맞을때 됬지': '맞을 때 됐지',
    '악 전기온다': '악 전기 온다',
    '무너질것같아': '무너질 것 같아',
    '갇힌거같아': '갇힌 거 같아',
    '차단기고장났나봐': '차단기 고장 났나 봐',
    '응급실에 데려다 주세요': '응급실에 데려다주세요',
    '뼈금갔어': '뼈 금 갔어',
    '스위치가이상해': '스위치가 이상해',
    '멀티탭에물들어갔어': '멀티탭에 물 들어갔어',
    '가스샜다': '가스 샜다',
    '문이 안열려요': '문이 안 열려요',
    '피복벗겨진거아냐': '피복 벗겨진 거 아냐',
    '전기선이끊어졌어': '전기선이 끊어졌어',
    '플러그조심해': '플러그 조심해',
    '그만그만 하란 말이야': '그만 그만하란 말이야',
    '펑하는 소리가 났어요': '펑 하는 소리가 났어요',
    '붕괴됬어': '붕괴됐어',
    '홍수조심해': '홍수 조심해',
    '산불난거아니야': '산불 난 거 아니야',
    '구급차어딨노': '구급차 어딨노',
    '스위치조심해': '스위치 조심해',
    '거긴 안돼': '거긴 안 돼',
    '소화기찾어': '소화기 찾아',
    '목이아픈것같아': '목이 아픈 것 같아',
    '차단기가내려갔어': '차단기가 내려갔어',
    '가스냄새나': '가스 냄새나',
    '안 돼요 제발 하지마세요': '안 돼요. 제발 하지 마세요',
    '어넘어진다': '어 넘어진다',
    '전기선이탔어': '전기선이 탔어',
    '뼈부러진거같아': '뼈 부러진 거 같아',
    '그만하세요': '그만 하세요',
    '목아파': '목 아파',
    '과부하됐어': '과부하 됐어',
    '플러그가탔어': '플러그가 탔어',
    '차단기고장났어': '차단기 고장 났어',
    '가스새고있는데': '가스 새고 있는데',
    '매몰된거아니야': '매몰된 거 아니야',
    '콘센트만지지마': '콘센트 만지지 마',
    '멀티탭이탔어': '멀티탭이 탔어',
    '멀티탭이이상해': '멀티탭이 이상해',
    '삐였구나': '삐었구나',
    '벌집건들지마': '벌집 건들지 마',
    '신고해줘': '신고해 줘',
    '과부하될것같아': '과부하 될 것 같아',
    '전기선 만지지마': '전기선 만지지 마',
    '멀티탭불량인가봐': '멀티탭 불량인가 봐',
    '콘센트가이상해': '콘센트가 이상해',
    '차단기가안올라가': '차단기가 안 올라가',
    '너 미쳤어 나한테 왜이래': '너 미쳤어 나한테 왜 이래',
    '머리를 부딛혔어요': '머리를 부딪혔어요',
    '무너질거같아': '무너질 거 같아',
    '과부화됐다': '과부하 됐다',
    '피복벗겨진것같은데': '피복 벗겨진 것 같은데',
    '콘센트 불량 인가봐': '콘센트 불량인가 봐',
    '가스냄새같아': '가스 냄새 같아',
    '건물바닥이 갈라졋어요': '건물 바닥이 갈라졌어요',
    '구급차필요해요': '구급차 필요해요',
    '터진다피해': '터진다. 피해',
    '골절같아': '골절 같아',
    '뼈부러진거아니야': '뼈 부러진 거 아니야',
    '뼈금갔지': '뼈 금 갔지',
    '눈조심해': '눈 조심해',
    '열나는것같아': '열나는 것 같아',
    '출혈막아': '출혈 막아',
    '과부하조심해': '과부하 조심해',
    '누전된것같은데': '누전된 것 같은데',
    '누전조심해': '누전 조심해',
    '차단기 고장났어': '차단기 고장 났어',
    '차단기가내려가': '차단기가 내려가',
    '유독가스같아': '유독가스 같아',
    '뼈부러졌겠다': '뼈 부러졌겠다',
    '탈골된거아니야': '탈골된 거 아니야',
    '도로를 막고있어요': '도로를 막고 있어요',
    '누전된것같아': '누전된 것 같아',
    '누전된거아냐': '누전된 거 아냐',
    '매몰된거같아': '매몰된 거 같아',
    '갇혔나봐': '갇혔나 봐',
    '금고어딨어': '금고 어딨어',
    '맞아야 정신차리지': '맞아야 정신 차리지',
    '소화기찾아와': '소화기 찾아와',
    '감전될까봐무서워': '감전될까 봐 무서워',
    '피복벗겨졌다': '피복 벗겨졌다',
    '콘센트가탔어': '콘센트가 탔어',
    '차단기 고장 났나봐': '차단기 고장 났나 봐',
    '차단기이상해': '차단기 이상해',
    '만지지 말란 말이예요': '만지지 말란 말이에요',
    '골절된것같아': '골절된 것 같아',
    '뼈금간거아니야': '뼈 금 간 거 아니야',
    '무너지고있어': '무너지고 있어',
    '붕괴될것같아': '붕괴될 것 같아',
    '현금내놔': '현금 내놔',
    '누전 된 거 아니야': '누전된 거 아니야',
    '멀티탭 불량인가봐': '멀티탭 불량인가 봐',
    '과부화 조심해': '과부하 조심해',
    '통증이온다': '통증이 온다',
    '붕괴위험있어': '붕괴 위험 있어',
    '문다물어': '문다. 물어',
    '도둑들었어': '도둑 들었어',
    '현금확인해봐': '현금 확인해 봐',
    '과부하될것같은데': '과부하 될 것 같은데',
    '감전조심해': '감전 조심해',
    '피복벗겨진것같아': '피복 벗겨진 것 같아',
    '스위치 만지지마': '스위치 만지지 마',
    '누전의심되는데': '누전 의심되는데',
    '차단기안올라가': '차단기 안 올라가',
    '배기통샌다': '배기통 샌다',
    '으미끄러워': '으 미끄러워',
    '은 발목이야': '으 발목이야',
    '119에 신고해주세요': '119에 신고해 주세요',
    '콘센트 만지지마': '콘센트 만지지 마',
    '탈골된거같아': '탈골된 거 같아',
    '건물이 흔들려요 건물 건물이 흔들려요': '건물이 흔들려요. 건물 건물이 흔들려요',
    '귀중품내놔': '귀중품 내놔',
    '귀금속확인해봐': '귀금속 확인해 봐',
    '구급차필요하다': '구급차 필요하다',
    '과부화 됐다': '과부하 됐다',
    '콘센트불량인가봐': '콘센트 불량인가 봐',
    '합선 된 거 아냐': '합선된 거 아냐',
    '가스냄새인가': '가스 냄새인가',
    '벌집조심해': '벌집 조심해',
    '뼈금갔네': '뼈 금 갔네',
    '지진인것같아': '지진인 것 같아',
    '비밀번호뭐냐니까': '비밀번호 뭐냐니까',
    '감전될것같아': '감전될 것 같아',
    '가스새는거같아': '가스 새는 거 같아',
    '귀금속없어졌어': '귀금속 없어졌어',
    '현금털렸어': '현금 털렸어',
    '여기 사람있어요': '여기 사람 있어요',
    '피복벗겨졌어': '피복 벗겨졌어',
    '가스샌다': '가스 샌다',
    '귀금속내놔': '귀금속 내놔',
    '금고열어': '금고 열어',
    '119좀불러줘': '119 좀 불러줘',
    '감전되서아파': '감전돼서 아파',
    '스위치 불량 인가봐': '스위치 불량인가 봐',
    '비상구로가': '비상구로 가',
    '눈이너무많이오는데': '눈이 너무 많이 오는데',
    '귀중품없어졌어': '귀중품 없어졌어',
    '고열에시달려': '고열에 시달려',
    '제발 때리지 마세요 다신 안 그럴게요': '제발 때리지 마세요. 다신 안 그럴게요',
    '떄리지 말란 말이야': '때리지 말란 말이야',
    '과부화됐어': '과부하 됐어',
    '유독가스 마시지마': '유독가스 마시지 마',
    '통증이오기시작해': '통증이 오기 시작해',
    '뼈금간것같아': '뼈 금 간 것 같아',
    '통증이안멈춰': '통증이 안 멈춰',
    '물지마': '물지 마',
    '귀중품어딨어': '귀중품 어딨어',
    '현금없어졌어': '현금 없어졌어',
    '귀중품확인해봐': '귀중품 확인해 봐',
    '목이부었어': '목이 부었어',
    '베인거아냐': '베인 거 아냐',
    '감전되면어떡해': '감전되면 어떡해',
    '감전돼서아파': '감전돼서 아파',
    '그만그만하란 말이야': '그만 그만하란 말이야',
    '정전 됐어요': '정전됐어요',
    '아이고 내돈': '아이고 내 돈',
    '제발 때리지 마세요 다신 안그럴께요': '제발 때리지 마세요. 다신 안 그럴게요',
    '비상구 어디있어': '비상구 어디 있어',
    '엘리베이터가 안움직남이요': '엘리베이터가 안 움직여요',
    '전기고장났다': '전기 고장났다',
    '전기선조심해': '전기선 조심해',
    '누전 된 것 같아': '누전된 것 같아',
    '물이차고있어': '물이 차고 있어',
    '112에신고해': '112에 신고해',
    '비밀번호뭐야': '비밀번호 뭐야',
    '경찰에신고해': '경찰에 신고해',
    '베인것같아': '베인 것 같아',
    '뼈 부러졌겠다': '뼈부러졌겠다',
    '누전 된 것 같은데': '누전된 것 같은데',
    '전기차단 됐다': '전기 차단됐다',
    '전기고장난거아냐': '전기 고장난 거 아냐',
    '정전된것같은데': '정전된 것 같은데',
    '전기차단된거아냐': '전기 차단된 거 아냐',
    '뼈금간거같아': '뼈 금 간 거 같아',
    '떄리지 마세요': '때리지 마세요',
    '여기 불이났어요': '여기 불이 났어요',
    '여기요 여기 사람있어요': '여기요 여기 사람 있어요',
    '고열이심해': '고열이 심해',
    '과호흡나타났어': '과호흡 나타났어',
    '합선 됐어': '합선됐어',
    '과부화조심해': '과부화 조심해',
    '코드 손대지마세요': '코드 손대지 마세요',
    '전기차단 된 거 아냐': '전기 차단 된 거 아냐',
    '눈보라심하다': '눈보라 심하다',
    '비가너무많이와': '비가 너무 많이 와',
    '화재경보울린다': '화재경보 울린다',
    '목이따가워': '목이 따가워',
    '과호흡왔어': '과호흡 왔어',
    '응급처받아야해': '응급처치 받아야 해',
    '의사불러야해': '의사 불러야 해',
    '전기나간것같은데': '전기 나간 것 같은데',
    '전기나갔나봐': '전기 나갔나 봐',
    '두꺼비집내려갔나봐': '두꺼비집 내려갔나 봐',
    '비상전원이 필요해': '비상 전원이 필요해',
    '전기차단됐어': '전기 차단됐어',
    '머리아파': '머리 아파',
    '은 팔목이야': '으 팔목이야',
    '떨어진거아니야': '떨어진 거 아니야',
    '물 난리가 났어요': '물난리가 났어요',
    '비가미쳤어': '비가 미쳤어',
    '신고좀 해 주세요': '심고 좀 해주세요',
    '도둑 맞았나 봐': '도둑맞았나 봐',
    '절도아니야': '절도 아니야',
    '숨을 못쉬겠어요': '숨을 못 쉬겠어요',
    '과호흡인가봐': '과호흡인가 봐',
    '응급처치빨리시작해': '응급처치 빨리 시작해',
    '의사불러주세요': '의사 불러주세요',
    '호흡곤란왔나봐': '호흡곤란 왔나 봐',
    '과부화 됐어': '과부하됐어',
    '정전됐나봐': '정전됐나 봐',
    '콘센트조심해': '콘센트 조심해',
    '차단기고장났나봐': '차단기 고장 났나 봐',
    '유독가스조심해': '유독가스 조심해',
    '비상구어딧어': '비상구 어딨어',
    '머리아파요': '머리 아파요',
    '물찬다': '물 찬다',
    '침수된거아니야': '침수된 거 아니야',
    '귀금속어디다뒀어': '귀금속 어디다 뒀어',
    '화재난것같은데': '화재 난 것 같은데',
    '고열인것 같아': '고열인 것 같아',
    '열이 안내려': '열이 안 내려',
    '의사있어야해': '의사 있어야 해',
    '호흡곤란인가봐': '호흡곤란인가 봐',
    '비상전원사용하자': '비상 전원 사용하자',
    '전기고장났나봐': '전기고장 났나 봐',
    '전기안되는거아냐': '전기 안 되는 거 아냐',
    '콘센트 만지지마': '콘센트 만지지 마',
    '비상전원없어': '비상 전원 없어',
    '가스고장이야': '가스 고장이야',
    '통증이안사라져': '통증이 안 사라져',
    '지붕이 날라갔어요': '지붕이 날아갔어요',
    '도로가 잠겼어요2': '도로가 잠겼어요',
    '눈이너무많이와': '눈이 너무 많이 와',
    '눈보라가심한데': '눈보라가 심한데',
    '홍수날거같아': '홍수 날 거 같아',
    '눈보라친다': '눈보라 친다',
    '물지말라고': '물지 말라고',
    '절도범잡아': '절도범 잡아',
    '경찰에전화해': '경찰에 전화해',
    '경찰좀불러줘': '경찰 좀 불러줘',
    '경찰필요해': '경찰 필요해',
    '화재난거아니야': '화재 난 거 아니야',
    '비상벨소리아냐': '비상벨 소리 아냐',
    '여기 사람 있단말이에요': '여기 사람 있단 말이에요',
    '고열인것같아': '고열인 것 같아',
    '고열인거같아': '고열인 거 같아',
    '심폐소생술시작해': '심폐소생술 시작해',
    '응급처치가필요해': '응급처치가 필요해',
    '응급처치해야해': '응급처치해야 해',
    '의사가필요해': '의사가 필요해',
    '의사불러줘': '의사 불러줘',
    '호흡곤란왔어': '호흡곤란 왔어',
    '화상입었어': '화상 입었어',
    '과부화 됐다': '과부하 됐다',
    '전기고장난것같아': '전기고장 난 것 같아',
    '전기차단된것같아': '전기 차단된 것 같아',
    '정전된거아냐': '정전된 거 아냐',
    '멀티탭 만지지마': '멀티탭 만지지 마',
    '비상전원쓰자': '비상 전원 쓰자',
    '비상전원 있어': '비상 전원 있어',
    '전기나갔어': '전기 나갔어',
    '전기차단 된 것 같은데': '전기 차단된 것 같은데',
    '전기차단 됐나봐': '전기 차단됐나 봐',
    '전기차단됐다': '전기 차단됐다',
    '전기 안되는데': '전기 안 되는데',
    '전기안되는데': '전기 안 되는데',
    '가스냄새가 나요': '가스 냄새가 나요',
    '유독가스마시지마': '유독가스 마시지 마'
}

# %%
data['text'] = data['text'].replace(correction_dict)

data
# Out:
#                                                file_name        text  label
# 0      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105083_labe...  내 몸에 손대지 마      1
# 1      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105137_labe...     만지지 마세요      1
# 2      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105448_labe...       만지지 마      1
# 3      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105512_labe...  내 몸에 손대지 마      1
# 4      test\audio\1.강제추행(성범죄)\1.강제추행(성범죄)_105589_labe...       만지지 마      1
# ...                                                  ...         ...    ...
# 78611         train\audio\9.가스사고\9.가스사고_709436_label.wav      가스 터진다      9
# 78612         train\audio\9.가스사고\9.가스사고_709441_label.wav      가스 터진다      9
# 78613         train\audio\9.가스사고\9.가스사고_709513_label.wav      가스 터진다      9
# 78614         train\audio\9.가스사고\9.가스사고_709576_label.wav  가스 터진 거 같아      9
# 78615         train\audio\9.가스사고\9.가스사고_709651_label.wav      가스 터졌다      9
#
# [78616 rows x 3 columns]

# %%
for i in range(len(data)):
    if data['text'][i] == '무너졌어요 무너졌어요':
        print(i)
# Out:
# 1488
# 20629
# 20734

# %%
data['file_name'][1488]
# Out:
# 'test\\audio\\11.붕괴사고\\11.붕괴사고_872029_label.wav'

# %%
data.to_csv('metadata.csv', index=False)
